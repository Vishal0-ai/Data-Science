# %% [markdown]
# # Taking Input from User

# %%
name = input("Enter your name")

print(name)
print(type(name))
# Out:
# Enter your name Vishal
# Vishal
# <class 'str'>

# %%
age = int(input("Enter your age: "))

print(age)
print(type(age))
# Out:
# Enter your age:  22
# 22
# <class 'int'>
