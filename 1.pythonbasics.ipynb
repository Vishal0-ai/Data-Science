# %%
# Variables
# we don't have to define it examples:-

# %%
name="Vishal"
age= 23

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
# Data Types 
# int, String, Float,
# List = [1, 2, 3]   Ordered, mutable collection
# Tuples = {1,2,23}  Ordered, immutable collection
