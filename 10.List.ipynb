# %% [markdown]
# # List and Its Method

# %%
numbers = [10, 20, 30, 40]
names = ["Amit", "Priya", "Rahul"]
mixed = [10, "Python", 3.14, True]

# %%
print(names[0])   
print(names[1])   
print(names[-1])
# Out:
# Amit
# Priya
# Rahul

# %%
print(numbers[1:4])   
print(numbers[:3])    
print(numbers[2:])    
print(numbers[::-1])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40]
# [40, 30, 20, 10]

# %% [markdown]
# ## List Methods

# %%
numbers = [40, 10, 30, 20, 10]

print("Original list:", numbers)

# 1. append()
numbers.append(50)
print("After append():", numbers)

# 2. insert()
numbers.insert(1, 15)
print("After insert():", numbers)

# 3. extend()
numbers.extend([60, 70])
print("After extend():", numbers)

# 4. remove()
numbers.remove(10)
print("After remove():", numbers)

# 5. pop()
removed_element = numbers.pop()
print("Element removed by pop():", removed_element)
print("After pop():", numbers)

# 6. index()
position = numbers.index(30)
print("Index of 30:", position)

# 7. count()
count = numbers.count(10)
print("Count of 10:", count)

# 8. sort()
numbers.sort()
print("After sort():", numbers)

# 9. reverse()
numbers.reverse()
print("After reverse():", numbers)

# 10. copy()
new_numbers = numbers.copy()
print("Copied list:", new_numbers)

# 11. clear()
numbers.clear()
print("After clear():", numbers)
# Out:
# Original list: [40, 10, 30, 20, 10]
# After append(): [40, 10, 30, 20, 10, 50]
# After insert(): [40, 15, 10, 30, 20, 10, 50]
# After extend(): [40, 15, 10, 30, 20, 10, 50, 60, 70]
# After remove(): [40, 15, 30, 20, 10, 50, 60, 70]
# Element removed by pop(): 70
# After pop(): [40, 15, 30, 20, 10, 50, 60]
# Index of 30: 2
# Count of 10: 1
# After sort(): [10, 15, 20, 30, 40, 50, 60]
# After reverse(): [60, 50, 40, 30, 20, 15, 10]
# Copied list: [60, 50, 40, 30, 20, 15, 10]
# After clear(): []
